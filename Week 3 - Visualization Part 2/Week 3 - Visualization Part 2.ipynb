# %% [markdown]
# # Data Visualization - Part 2

# %%
#importing the libraries

import numpy as np #linear algebra
import pandas as pd #data preprocessing
import matplotlib.pyplot as plt #visualization similar to ggplot2 on R
import seaborn as sns
import plotly as py
import plotly.express as px
import plotly.graph_objects as go
import scipy.stats as stats

# %%
data1 = pd.read_csv("C:\\Users\\Abraham\\Documents\\abraham\\data mining - iup lab assistant\\data\\Iris.csv")
display(data1)
data2 = pd.read_csv("C:\\Users\\Abraham\\Documents\\abraham\\data mining - iup lab assistant\\data\\cars.csv")
display(data2)
data3 = pd.read_csv("C:\\Users\\Abraham\\Documents\\abraham\\data mining - iup lab assistant\\data\\StudentsPerformance.csv")
display(data3)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# CORRELATION PLOT
#
# A heatmap is basically a two-dimensional plot which is mainly used to analyze the correlation between the different fields in a dataset. A heatmap is divided in square boxes that are colored with a specific color representing the correlation between the two fields it corresponds to.

# %%
irisdata = data1[["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"]]

#correlation plot or heatmap
correlation_matrix = irisdata.corr()
sns.heatmap(correlation_matrix, 
            annot = True, #annotating the plot with numeric values
            cmap = "mako", #colormap style
            fmt = "0.2f", #format for annotiations in decimal
            linewidth = 0.5)
plt.title('Correlation Heatmap')
plt.xlabel('Features')
plt.ylabel('Features')
plt.xticks(rotation = 45)
plt.show()

# %%
KERNEL DENSITY PLOT

KDE plot is used to visualize the probability density of a continuous variable

# %%
#kernel density plot

sns.kdeplot(x=data1["SepalLengthCm"], 
            hue = data1["Species"], # adding different colors to the plot for each unique value 
            linewidth = 0.5, 
            fill = True, 
            multiple = "layer", #specifies how multiple KDE plots are displayed when there are multiple hue levels
            cbar = True, #add a colorbar
            palette = "crest", 
            alpha = 0.4 #transparency, the lower the more transparent)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Density'>

# %% [markdown]
# DISTPLOT
#
# A distplot is used to plot a histogram along with the kernel density estimate of a particular variable. Such a plot is used with discrete or continuous data. This function basically combines a histogram and kdeplot.

# %%
#distplot

sns.distplot(irisdata["SepalWidthCm"], 
             bins = 25, 
             kde = True, 
             rug = True, #adding rug plot along the x-axis
             color = "green", 
             hist_kws = {"alpha":0.3}, #histogram transparency
             kde_kws = {"linewidth":2})
# Out:
# C:\Users\Abraham\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Abraham\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Density'>

# %% [markdown]
# BOX PLOT
#
# Box plot is used to get statistical information about distribution. It shows the median, maximum, minimum, 25th percentile and 75th percentile values. It is also good to explore outliers in the dataset.

# %%
#basic box plot

sns.boxplot(y=data3["math score"])
# Out:
# <AxesSubplot:ylabel='math score'>

# %%
#grouped box plot

sns.boxplot(x=data3["gender"], y=data3["math score"],
           palette = {"#e63946", "#457b9d"})
# Out:
# <AxesSubplot:xlabel='gender', ylabel='math score'>

# %%
#grouped box plot with subgroups

sns.boxplot(x="gender",
            y="math score",
            hue="test preparation course",
            data=data3,
            palette="Blues",
            width=0.4)
plt.show()

# %% [markdown]
# VIOLIN PLOT
#
# Violin Plot is used to visualize the distribution of a numeric variable for one or several groups.

# %%
#basic violin plot

sns.violinplot(x=data1["Species"], y=data1["SepalLengthCm"], 
               palette = {"#f5cac3", "#f7ede2", "#84a59d"})
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalLengthCm'>
